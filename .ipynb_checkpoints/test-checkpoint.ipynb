# %%
import pandas as pd
df = pd.read_csv("static/data/NBA.csv")
df = df[df.columns.tolist()[1:]]
df
# Out:
#               id                 Name  From    To  Height      Weight  Year  \
# 0       ablefo01          Forest Able  1957  1957  190.50   81.646627  1957
# 1      abdulka01  Kareem Abdul-Jabbar  1970  1989  218.44  102.058283  1970
# 2      abdulka01  Kareem Abdul-Jabbar  1970  1989  218.44  102.058283  1971
# 3      abdulka01  Kareem Abdul-Jabbar  1970  1989  218.44  102.058283  1972
# 4      abdulka01  Kareem Abdul-Jabbar  1970  1989  218.44  102.058283  1973
# ...          ...                  ...   ...   ...     ...         ...   ...
# 22995  zubaciv01          Ivica Zubac  2017  2022  213.36  108.862169  2018
# 22996  zubaciv01          Ivica Zubac  2017  2022  213.36  108.862169  2019
# 22997  zubaciv01          Ivica Zubac  2017  2022  213.36  108.862169  2020
# 22998  zubaciv01          Ivica Zubac  2017  2022  213.36  108.862169  2021
# 22999  zubaciv01          Ivica Zubac  2017  2022  213.36  108.862169  2022
#
# ...

# %%
import utils
df['score2'] = df.apply(utils.calc_score)
df
# Out:
# (0         ablefo01
# 1        abdulka01
# 2        abdulka01
# 3        abdulka01
# 4        abdulka01
#            ...
# 22995    zubaciv01
# 22996    zubaciv01
# 22997    zubaciv01
# 22998    zubaciv01
# 22999    zubaciv01
# Name: id, Length: 23000, dtype: object,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [2], in <module>
#       1 import utils
# ----> 2 df['score2'] = df.apply(utils.calc_score)
#       3 df
#
# File d:\pycharm projects\basketball-stats project\.venv\lib\site-packages\pandas\core\frame.py:8827, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8816 from pandas.core.apply import frame_apply
#    8818 op = frame_apply(
#    8819     self,
#    8820     func=func,
#    (...)
#    8825     kwargs=kwargs,
#    8826 )
# -> 8827 return op.apply().__finalize__(self, method="apply")
#
# ...
